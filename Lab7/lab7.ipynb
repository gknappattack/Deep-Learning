# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clone()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext spacy
# !python -m spacy download en
# !python -m spacy download es
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"
# Out:
# Requirement already satisfied: torchtext in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext) (1.21.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext) (4.62.3)
# Requirement already satisfied: torch==1.10.0 in /usr/local/lib/python3.7/dist-packages (from torchtext) (1.10.0+cu111)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.10.0->torchtext) (3.10.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (4.11.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (3.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (3.0.4)
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 5.1 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.21.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.11.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
# Collecting es_core_news_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.2.5/es_core_news_sm-2.2.5.tar.gz (16.2 MB)
#      |████████████████████████████████| 16.2 MB 5.2 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from es_core_news_sm==2.2.5) (2.2.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (7.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.21.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (4.62.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (0.9.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (57.4.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (4.11.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.10.0.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (2021.10.8)
# Building wheels for collected packages: es-core-news-sm
#   Building wheel for es-core-news-sm (setup.py) ... done
#   Created wheel for es-core-news-sm: filename=es_core_news_sm-2.2.5-py3-none-any.whl size=16172933 sha256=d4fc00314c31da17ee61ee7b2f26f3241cdcc6262a8ccc0cb12dd50a4236f09e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_i5cm7uk/wheels/21/8d/a9/6c1a2809c55dd22cd9644ae503a52ba6206b04aa57ba83a3d8
# Successfully built es-core-news-sm
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/es_core_news_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/es
# You can now load the model via spacy.load('es')
# --2022-02-24 18:56:33--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8617078 (8.2M) [text/plain]
# Saving to: ‘./spanish’
#
# ./spanish           100%[===================>]   8.22M  --.-KB/s    in 0.09s
#
# 2022-02-24 18:56:34 (94.1 MB/s) - ‘./spanish’ saved [8617078/8617078]
#
# --2022-02-24 18:56:34--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7755011 (7.4M) [text/plain]
# Saving to: ‘./english’
#
# ./english           100%[===================>]   7.40M  --.-KB/s    in 0.09s
#
# 2022-02-24 18:56:34 (86.9 MB/s) - ‘./english’ saved [7755011/7755011]

# %% [markdown]
# #Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)
    
class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))
    
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)


    
class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)
    
class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)
 
    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)
    
def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ##Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
def attention(query, key, value, mask):
    # Compute 'Scaled Dot Product Attention' torch.bmm, torch.mm, and torch.matmul
    dim_size = query.shape[2]

    # Transpose of key matrix for multiplication
    k_T = torch.permute(key, (0,2,1))

    # q * K^T matrix
    q_k = torch.matmul(query, k_T)
    
    # scores = QK^T/scale
    scores = q_k / np.sqrt(dim_size)
    
    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
        
    # output = softmax(scores)(V)
    output = torch.softmax(scores, dim=-1)

    # Outputs * Value matrix
    output = torch.matmul(output, value)
    
    return output

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()

        # Save necessary dimension values
        self.d_model = d_model
        self.d_k = d_model // h  # Size of reduced embedding output for each linear layer for multiheaded attention
        self.h = h

        
        # Make an attention head (linear layers for q, k, and v)
        head = nn.ModuleList([nn.Linear(d_model, self.d_k), nn.Linear(d_model, self.d_k), nn.Linear(d_model, self.d_k)])
        
        
        # Make h copies of the attention head (Hint: See the `clone()` helper function)
        self.heads = clones(head, h)
        
        # Initialize dropout and final linear layer
        self.dropout = nn.Dropout(dropout)
        self.out = nn.Linear(d_model, d_model)

    def forward(self, query, key, value, mask):

        outputs = []

        # Q layer, v layer, k_layer

        # Loop through each attention head
        for i, head in enumerate(self.heads):

          # Get linear layer for query, key and value from attention head module list
          q_layer = head[0]
          v_layer = head[1]
          k_layer = head[2]

          # Pass each input through respective linear layer
          query_out = q_layer(query)
          value_out = v_layer(value)
          key_out = k_layer(key)

          # Calculate attention
          scores = attention(query_out, key_out, value_out, mask)

          # Drop out layer
          scores = self.dropout(scores)

          # Append score for current head to list
          outputs.append(scores)

        # Concat all scores back into list along embedding dimension
        concat = torch.cat(outputs, dim=-1)

        # Pass through output linear layer
        output = self.out(concat)

        return output

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)], 
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()
        
        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy
        
        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
        
    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
    
    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
    
global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext.legacy import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es')
spacy_en = spacy.load('en')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD, 
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
spanish_text = open('./spanish','r')
english_text = open('./english', 'r')
english_lines = list(english_text)
spanish_lines = list(spanish_text)

fields = (["src", SRC], ["trg", TGT])
examples = [torchtext.legacy.data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = torchtext.legacy.data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)), 
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)
            
        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)

    
def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg, 
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ##Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 3
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=True)
    valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=False)

    model_opt = torch.optim.Adam(model.parameters(), lr=5e-4)
    for epoch in range(n_epochs):
        model.train()
        print("Epoch: ", epoch)
        run_epoch((rebatch(pad_idx, b) for b in train_iter), 
                  model, 
                  LossFunction(model.generator, criterion, model_opt))
        model.eval()
scope()
# Out:
# Epoch:  0
# Epoch Step: 1 Loss: 8.725221 Tokens per Sec: 1533.948975
# Epoch Step: 51 Loss: 6.034006 Tokens per Sec: 7533.876465
# Epoch Step: 101 Loss: 5.799527 Tokens per Sec: 7554.838379
# Epoch Step: 151 Loss: 5.286666 Tokens per Sec: 7719.892090
# Epoch Step: 201 Loss: 4.951530 Tokens per Sec: 7693.977051
# Epoch Step: 251 Loss: 5.343127 Tokens per Sec: 7436.755371
# Epoch Step: 301 Loss: 5.267788 Tokens per Sec: 7341.217773
# Epoch Step: 351 Loss: 5.695462 Tokens per Sec: 7142.806152
# Epoch Step: 401 Loss: 5.215384 Tokens per Sec: 7323.225098
# Epoch Step: 1201 Loss: 3.439061 Tokens per Sec: 7279.527832
# Epoch Step: 1251 Loss: 2.407561 Tokens per Sec: 7654.484863
# Epoch Step: 1301 Loss: 3.844531 Tokens per Sec: 7617.079590
# Epoch:  2
# Epoch Step: 1 Loss: 2.600528 Tokens per Sec: 3437.181885
# Epoch Step: 51 Loss: 2.694855 Tokens per Sec: 7204.922363
# Epoch Step: 101 Loss: 2.146286 Tokens per Sec: 7794.072754
# Epoch Step: 151 Loss: 2.769397 Tokens per Sec: 7899.385742
# Epoch Step: 201 Loss: 3.002333 Tokens per Sec: 7482.014160
# Epoch Step: 251 Loss: 2.514005 Tokens per Sec: 7250.206543
# Epoch Step: 301 Loss: 2.484268 Tokens per Sec: 7659.756836
# Epoch Step: 351 Loss: 2.932739 Tokens per Sec: 7373.449707
# Epoch Step: 401 Loss: 2.534383 Tokens per Sec: 7445.731445
# Epoch Step: 451 Loss: 1.752332 Tokens per Sec: 7391.719727
# Epoch Step: 501 Loss: 2.040961 Tokens per Sec: 7781.987793
# Epoch Step: 551 Loss: 1.830250 Tokens per Sec: 7259.241699
# Epoch Step: 601 Loss: 2.209687 Tokens per Sec: 7502.221191
# Epoch Step: 651 Loss: 2.668766 Tokens per Sec: 7422.882324
# Epoch Step: 701 Loss: 2.786244 Tokens per Sec: 7376.206543
# Epoch Step: 751 Loss: 2.684795 Tokens per Sec: 7611.749512
# Epoch Step: 801 Loss: 2.673623 Tokens per Sec: 7426.790039
# Epoch Step: 851 Loss: 2.077224 Tokens per Sec: 7689.860840
# Epoch Step: 901 Loss: 2.024697 Tokens per Sec: 7427.881348
# Epoch Step: 951 Loss: 2.035403 Tokens per Sec: 7381.045410
# Epoch Step: 1001 Loss: 3.511565 Tokens per Sec: 7493.472656
# Epoch Step: 1051 Loss: 2.089942 Tokens per Sec: 7182.488281
# Epoch Step: 1101 Loss: 1.853989 Tokens per Sec: 7279.825684
# Epoch Step: 1151 Loss: 2.900135 Tokens per Sec: 7393.837402
# Epoch Step: 1201 Loss: 2.580241 Tokens per Sec: 7384.983887
# Epoch Step: 1251 Loss: 2.599983 Tokens per Sec: 6944.957520
# Epoch Step: 1301 Loss: 2.401455 Tokens per Sec: 7731.458496

# %% [markdown]
# ## Translate

# %% [markdown]
# ## Translation output with 3 epochs of training

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)
    
for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask, 
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()
    
    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	Élder Ulisses Soares
# Translation:	Elder Ulisses Soares
# Target:		Elder Ulisses Soares
#
# Spanish:	Él promete :
# Translation:	He promises :
# Target:		His promise is :
#
# Spanish:	Sesión General del Sacerdocio
# Translation:	Priesthood Session
# Target:		General Priesthood Session
#
# Spanish:	Véase Mosíah 18:21 .
# Translation:	See Mosiah 18:8–9 .
# Target:		See Mosiah 18:21 .
#
# Spanish:	Véase Romanos 3:23 .
# Translation:	See Romans 10:3–5 .
# Target:		See Romans 3:23 .
#
# Spanish:	Testifico de Cristo .
# Translation:	I testify of Christ .
# Target:		I testify of Christ .
#
# Spanish:	¿ Por qué yo ?
# Translation:	Why I ?
# Target:		Why me ?
#
# Spanish:	Isaías 2:2 ; 11:12 .
# Translation:	Isaiah 2:2 ;
# Target:		Isaiah 2:2 ; 11:12 .
#
# Spanish:	Ezequiel <unk> , 10 .
# Translation:	Ezekiel ’s arrival , 10 .
# Target:		Ezekiel <unk> , 10 .
#
# Spanish:	Números 12:6 , 8 .
# Translation:	Months later , 8 .
# Target:		Numbers 12:6 , 8 .
#
# Spanish:	Cito de su historia :
# Translation:	I quote his story :
# Target:		I quote from his history :
#
# Spanish:	y ellas no mejorarán .
# Translation:	And they did not be clean .
# Target:		Those things will not get better .
#
# Spanish:	Sesión del domingo por la mañana
# Translation:	Sunday Morning Session
# Target:		Sunday Morning Session
#
# Spanish:	Gratitud en el día de reposo
# Translation:	Gratitude in the Sabbath
# Target:		Gratitude on the Sabbath Day
#
# Spanish:	1 . Aprender nuestro deber .
# Translation:	1 .
# Target:		1 . Learning Our Duty
#
# Spanish:	Deuteronomio 4:9 ; cursiva agregada .
# Translation:	Deuteronomy 2:28 ; emphasis added .
# Target:		Deuteronomy 4:9 ; emphasis added .
#
# Spanish:	1 Nefi 2:11 , 12 .
# Translation:	1 Nephi 2:11 , 12 .
# Target:		1 Nephi 2:11 , 12 .
#
# Spanish:	ha de volver a nosotros .
# Translation:	He has to return to us .
# Target:		Comes back into our own .
#
# Spanish:	¿ Permanecemos en lugares santos ?
# Translation:	Do we stand in holy places ?
# Target:		Are we standing in holy places ?
#
# Spanish:	Caroline decidió seguir el plan .
# Translation:	Mary decided to follow the plan .
# Target:		Caroline made the choice to follow the plan .
#
# Spanish:	Aquí para servir en una causa noble
# Translation:	Here for serve in a Good cause
# Target:		Here to Serve a Righteous Cause
#
# Spanish:	Mi urgencia los sorprendió un poco .
# Translation:	My response was a little .
# Target:		My urgency startled them a little .
#
# Spanish:	Véase Juan 15:26 ; Romanos 8:16 .
# Translation:	See John 16:33 ; Romans 8:16–17 .
# Target:		See John 15:26 ; Romans 8:16 .
#
# Spanish:	Soy el Hijo de Dios ” .
# Translation:	I am the Son of God . ”
# Target:		I am the Son of God . ”
#
# Spanish:	Consideren de qué pecados debemos arrepentirnos .
# Translation:	Consider what sins should repent .
# Target:		Consider what sins we need to repent of .
#
# Spanish:	Me encanta la historia de la Iglesia .
# Translation:	I love the history of the Church .
# Target:		I love Church history .
#
# Spanish:	Él sabe la mejor manera de ayudarnos .
# Translation:	He knows the best way .
# Target:		He knows best how to help .
#
# Spanish:	Doctrina y Convenios 93:1 ; cursiva agregada .
# Translation:	Doctrine and Covenants 88:6 ; emphasis added .
# Target:		Doctrine and Covenants 93:1 ; emphasis added .
#
# Spanish:	Sin ella , yo no estaría aquí ;
# Translation:	Without her , I would not be here .
# Target:		I would not be here without her .
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:	In the name of Jesus Christ , amen .
# Target:		In the name of Jesus Christ , amen .
#
# Spanish:	Se había desatado la Segunda Guerra Mundial .
# Translation:	He had been the Second Coming of World .
# Target:		World War II had exploded across the world .
#
# Spanish:	Incluya la conferencia general en su diario vivir
# Translation:	Conference Talks Available
# Target:		Include General Conference in Your Day - to - Day Life
#
# Spanish:	Mantener a la familia es una actividad consagrada .
# Translation:	To the family is a consecrated activity .
# Target:		<unk> is a consecrated activity .
#
# Spanish:	¿ Cómo te sientes cuanto te arrepientes ? :
# Translation:	How do you feel you feel ?
# Target:		How do you feel when you repent ?
#
# Spanish:	Véase Juan 14:26 ; D. y C. 35:19 .
# Translation:	See John 14:26 ; Doctrine and Covenants 45:26 .
# Target:		See John 14:26 ; Doctrine and Covenants 35:19 .
#
# Spanish:	Se me ha pedido que dirija esta sesión .
# Translation:	I has asked me to consider this session .
# Target:		I have been asked to conduct this session .
#
# Spanish:	“ El Salvador los sanaba a todos ” .
# Translation:	“ The Savior will bring all . ”
# Target:		“ The Savior did heal them every one . ”
#
# Spanish:	Pueden orar cuando el coro vaya a cantar .
# Translation:	You can pray when the choir will sing .
# Target:		You can pray as the choir is about to sing .
#
# Spanish:	También será nuestra la senda de la tentación .
# Translation:	It will be also our path of temptation .
# Target:		The path of temptation too will be the path of each .
#
# Spanish:	La conferencia general : Fortalece la fe y el testimonio
# Translation:	Conference Talks Available
# Target:		General Conference : Strengthening Faith and Testimony
#
# Spanish:	¡ Allí está , arrastrándose hacia el pantano ! .
# Translation:	There is a way to the edge of the sea !
# Target:		There he is crawling into a <unk> !
#
# Spanish:	Sabemos que el Señor hace intrépidos a Sus siervos .
# Translation:	We know that the Lord does not have His servants .
# Target:		We know the Lord makes His servants bold .
#
# Spanish:	Quinto , no olviden que el Señor las ama .
# Translation:	Fifth , please not forget the Lord loves you .
# Target:		Fifth , forget not that the Lord loves you .
#
# Spanish:	“ El sacerdocio se dio primeramente a Adán ” .
# Translation:	“ The priesthood gave unto Adam . ”
# Target:		“ The Priesthood was first given to Adam . ”
#
# Spanish:	Ahora espero con anhelo pertenecer a un nuevo cuórum .
# Translation:	I hope I will pray with a new quorum .
# Target:		Now I look forward to belonging to a new quorum .
#
# Spanish:	Haríamos bien en seguir el ejemplo de nuestro Maestro .
# Translation:	We would do good to follow the example of our Master .
# Target:		We would do well to follow the example of our Master .
#
# Spanish:	Nos sentamos y hablamos acerca de qué debíamos hacer .
# Translation:	We were going to go about what we should do .
# Target:		We sat down , and we talked about what we should do . We made a plan .
#
# Spanish:	Primera Consejera de la Presidencia General de la Sociedad de Socorro
# Translation:	First Counselor in the Relief Society General Presidency
# Target:		First Counselor in the Relief Society General Presidency
#
# Spanish:	Cuando el <unk> aflige a su rival , se regocijan .
# Translation:	When you are committed to your abilities , you will continue to be strengthened .
# Target:		When ill fortune afflicts their rival , they rejoice .
#
# Spanish:	El camino del sacerdocio es un trayecto lleno de gozo .
# Translation:	The Lord ’s way is a journey filled with joy .
# Target:		The priesthood path is a journey filled with joy .
#
# Spanish:	La preparación en el sacerdocio : “ Necesito tu ayuda ”
# Translation:	Priesthood preparation in the priesthood : “ I need your help ”
# Target:		Preparation in the Priesthood : “ I Need Your Help ”
#
# Spanish:	Mis hijos hacen muchas de sus tareas escolares por internet .
# Translation:	My children do many of their school .
# Target:		My children do much of their schoolwork through the Internet .
#
# Spanish:	Me dijo que guardara el dólar y no lo perdiera .
# Translation:	He said that I would not be able to lose it .
# Target:		He told me to keep the dollar and never lose it .
#
# Spanish:	Como verdaderos hermanos , <unk> por ellos y los fortalecerán .
# Translation:	As true brethren , you will be able to obey .
# Target:		Like a true brother , you will watch over and strengthen them .
#
# Spanish:	Él sabe cuándo están perdidos y Él sabe dónde están .
# Translation:	He knows when they are lost and He knows .
# Target:		He knows when you are lost , and He knows where you are .
#
# Spanish:	" No os dejaré huérfanos ; vendré a vosotros " .
# Translation:	" I will not leave you . "
# Target:		" I will not leave you comfortless : I will come to you , " He promises .
#
# Spanish:	Después , deben imprimir un formulario de Solicitud de ordenanzas familiares .
# Translation:	After the arrival of the ordinances of the ordinances .
# Target:		Then you print out a Family Ordinance Request .
#
# Spanish:	Él contestará nuestras oraciones ( véase D. y C. 112:10 ) .
# Translation:	He will answer our prayers ( see D&C 88:118 ) .
# Target:		He will answer our prayers ( see D&C 112:10 ) .
#
# Spanish:	El cuarto enseña la importancia de los principios y ordenanzas básicos .
# Translation:	The dedication teaches the importance of the principles and basic ordinances .
# Target:		The fourth teaches the importance of basic principles and ordinances .
#
# Spanish:	Los jóvenes deben saber cómo buscar la guía del Padre Celestial .
# Translation:	The youth must know how to seek the guidance of Heavenly Father .
# Target:		Our youth must know how to seek Heavenly Father ’s guidance .
#
# Spanish:	“ Aunque colmados de pesar ” , Himnos , Nº 63 .
# Translation:	“ Though ye shall be filled with sorrow , ” Hymns , no .
# Target:		“ Though <unk> Trials , ” Hymns , no . 122 .
#
# Spanish:	El Señor confía en aquel que es obediente a Sus mandamientos .
# Translation:	The Lord trusts His commandments .
# Target:		One who is obedient to His commandments is trusted of the Lord .
#
# Spanish:	Recordar cuando fue llevado ante Pilato y Herodes para ser juzgado .
# Translation:	To remember when He was sent to be .
# Target:		To remember when He was taken to Pilate and to Herod for trial .
#
# Spanish:	Ella había experimentado el poder sanador de la expiación del Salvador .
# Translation:	She had experienced the healing power of the Savior .
# Target:		She had felt the healing power of the Savior ’s Atonement for her .
#
# Spanish:	El Señor les aconsejó “ sufrir con paciencia sus aflicciones ” .
# Translation:	The Lord counseled them to “ suffer patience . ”
# Target:		They were counseled by the Lord to “ bear with patience their afflictions . ”
#
# Spanish:	haciendo caso omiso a mis súplicas de que no fueran tan rápido .
# Translation:	Just as you begin to my reaction to you do n’t have to get so much .
# Target:		They ignored my petitions to slow down .
#
# Spanish:	Él es “ … la luz que brilla en las tinieblas ” .
# Translation:	He is “ light that is the light . ”
# Target:		He is “ the light which shineth in darkness . ”
#
# Spanish:	Pocos sentimientos se comparan con las tiernas emociones de convertirse en padre .
# Translation:	A feelings of righteous tender mercies in love .
# Target:		Few feelings compare with the tender emotions of becoming a parent .
#
# Spanish:	Al igual que el hijo pródigo , “ volvió en sí ” .
# Translation:	Like the prodigal son , “ He became . ”
# Target:		Like the prodigal son , “ he came to himself . ”
#
# Spanish:	Con el espíritu de esa instrucción es que me dirijo a ustedes .
# Translation:	With the spirit of this inspired instruction is to you .
# Target:		It is in the spirit of that instruction that I address you .
#
# Spanish:	Véase UNICEF , “ Young Child <unk> and Development ” , <unk> .
# Translation:	See “ Fourteen Fundamentals , and A creative thing , ” scriptures.lds.org .
# Target:		See UNICEF , “ Young Child Survival and Development , ” <unk> .
#
# Spanish:	Escuchamos también ejemplos de ello entre personas de fe en otras iglesias .
# Translation:	We also hear examples from the faith of faith in other faiths .
# Target:		We also hear examples of this among people of faith in other churches .
#
# Spanish:	Tomamos el nombre de Cristo sobre nosotros en las aguas del bautismo .
# Translation:	We take the name of Christ upon ourselves the waters of baptism .
# Target:		We take the name of Christ upon us in the waters of baptism .
#
# Spanish:	Yo también quisiera expresar mi amor por mi amado compañero , Craig .
# Translation:	I also would like to express my love for my beloved companion , Craig .
# Target:		I too would like to express my love for my beloved companion , Craig .
#
# Spanish:	Como pueden ver , no memoricé todo el versículo palabra por palabra .
# Translation:	As you can see , I did not know the word of word .
# Target:		As you can see , I did n’t memorize the entire verse word for word .
#
# Spanish:	Me <unk> a la Iglesia cuando sepa que es lo correcto ” .
# Translation:	I marvel as the Church sees it . ”
# Target:		I will join the Church when I know it is the right thing to do . ”
#
# Spanish:	El presidente Packer y su esposa en el Templo de Brigham City , Utah
# Translation:	President Packer and his wife in Brigham Young University , Utah Utah Utah .
# Target:		President and Sister Packer at Brigham City Utah Temple
#
# Spanish:	Él hizo una referencia específicamente a eso anoche en la reunión del sacerdocio .
# Translation:	He did have been given this last day .
# Target:		He referred specifically to that last night in priesthood meeting .
#
# Spanish:	¡ Es hora de ponerse de pie y defender Su plan otra vez !
# Translation:	It is a time to stand and to stand up .
# Target:		It is time to stand up and defend His plan again !
#
# Spanish:	Ahora nos hallamos en todas partes del mundo , y somos catorce millones .
# Translation:	Now we are in all everywhere .
# Target:		We are now everywhere in the world , 14 million of us .
#
# Spanish:	El obispo me llamó a ser su primer ayudante del quórum de presbíteros .
# Translation:	The bishop called me to be his first first first first quorum .
# Target:		The bishop called me to be his first assistant in the priests quorum .
# Target:		The Lord said , “ I will tell you in your mind and in your heart . ”
#
# Spanish:	Por muchos años permaneció así hasta que finalmente se decidió que la Frauenkirche sería reconstruida .
# Translation:	For many years had been so waiting for the air .
# Target:		For many years it remained that way , until finally it was determined that the Frauenkirche would be rebuilt .
#
# Spanish:	Ruego que todos nos esforcemos por tener la confianza para declarar : “ Soy mormón .
# Translation:	I pray that we will have the trust to declare to declare : “ I ’m Mormon .
# Target:		I pray that each of us will put forth the effort to be able to confidently declare , “ I ’m a Mormon .
#
# Spanish:	A esta organización divinamente señalada y dirigida por el sacerdocio se le llama Sociedad de Socorro .
# Translation:	To this organization and provided priesthood .
# Target:		This divinely appointed and priesthood - directed organization is called Relief Society .
#
# Spanish:	Los discursantes son seleccionados de entre las Autoridades Generales y los Oficiales Generales de la Iglesia .
# Translation:	Those in the General Authorities and General Authorities of the Church .
# Target:		Speakers are selected from the General Authorities and general officers of the Church .
#
# Spanish:	Un ejemplo de una de esas oportunidades apareció en un artículo <unk> en octubre de 1981 .
# Translation:	A example of these opportunities came to a copy in general conference .
# Target:		An example of such an opportunity appeared in a newspaper article in October 1981 .
#
# Spanish:	“ y cuando están separados , el hombre no puede recibir una plenitud de gozo ” .
# Translation:	“ And when you are serious , man can not receive a fulness of joy . ”
# Target:		“ And when separated , man can not receive a fulness of joy . ”
#
# Spanish:	Lo que necesitaba saber en cuanto a los susurros lo encontré en el Libro de Mormón .
# Translation:	What needed to know about the whisperings of the Book of Mormon .
# Target:		What I needed to know about the promptings I found in the Book of Mormon .
#
# Spanish:	Muchas de esas pruebas y tribulaciones podrían <unk> mediante la obediencia a las leyes de Dios .
# Translation:	Many trials and tribulations could be able to ignore obedience to the laws of God .
# Target:		Many of these trials and tribulations could be avoided by obedience to God ’s laws .
#
# Spanish:	Crean que el permanecer firmes y fieles a las verdades del Evangelio es de fundamental importancia .
# Translation:	Believe that the strong and faithful truths to the gospel is of importance .
# Target:		Believe that remaining strong and faithful to the truths of the gospel is of utmost importance .
#
# Spanish:	Al “ visitar la casa de todos los miembros ” , no sean temerosos ni tímidos .
# Translation:	As “ visit the house of all members , ” not be used or Woman .
# Target:		As you “ visit the house of each member , ” be not fearful or <unk> .
#
# Spanish:	Julie y yo llevamos más de tres años “ meditizando ” un versículo a la semana .
# Translation:	Julie and I decided to dedicate three years ago .
# Target:		Julie and I have been ponderizing a verse a week for more than three years now .
#
# Spanish:	Les leía cuentos antes de dormir y oraba con ellos antes de ponerlos en la cama .
# Translation:	I read you over my own and prayed with them before you were going to go before .
# Target:		I read them bedtime stories and said prayers with them before tucking them into bed at night .
#
# Spanish:	Nuestra alma se conmueve al ver imágenes de muerte , sufrimiento y desesperación en la televisión .
# Translation:	Our souls is a desire to see the images of death and in the television .
# Target:		We are moved in our souls by television images of death , acute suffering , and despair .
#
# Spanish:	Cuando yo era niño , solía mirar el cielo estrellado y meditar y sentir Su presencia .
# Translation:	When I was a child , I would look to heaven and feel His presence .
# Target:		As a boy , I used to gaze into the starry sky and ponder and feel His presence .
# Target:		Photographs in Salt Lake City were taken by Welden C. Andersen , <unk> Bell , Cody Bell , Janae Bingham , Ale Borges , Randy Collier , Mark Davis , Nate Edwards , Brian Nicholson , Leslie Nilsson , Matt Reier , Bradley <unk> , and Christina Smith ; of the Cavalcante family , courtesy of Aroldo Cavalcante ; in Athens , Georgia , USA , by Whitney <unk> ; in <unk> County , California , USA , by Erik <unk> ; of Openshaw family members , courtesy of the Openshaw family ; in <unk> , India , by Wendy <unk> <unk> ; in <unk> and <unk> , Norway , by Ashlee Larsen ; in Kyiv , Ukraine , by <unk> <unk> ; in San Pedro , <unk> , by Josué Peña ; in <unk> , Chile , by <unk> Jeanne Randall ; in <unk> , <unk> , Mexico , by <unk> Castañeda Reyes ; in <unk> City , <unk> , Philippines , by Danny <unk> .

# %% [markdown]
# ## Translation output with 8 epochs of training

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)
    
for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask, 
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()
    
    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	Élder Ulisses Soares
# Translation:	Elder Ulisses Soares
# Target:		Elder Ulisses Soares
#
# Spanish:	Él promete :
# Translation:	He promises :
# Target:		His promise is :
#
# Spanish:	Sesión General del Sacerdocio
# Translation:	General Priesthood Session
# Target:		General Priesthood Session
#
# Spanish:	Véase Mosíah 18:21 .
# Translation:	See Mosiah 18:21 .
# Target:		See Mosiah 18:21 .
#
# Spanish:	Véase Romanos 3:23 .
# Translation:	See Romans 3:23 .
# Target:		See Romans 3:23 .
#
# Spanish:	Testifico de Cristo .
# Translation:	I testify of Christ .
# Target:		I testify of Christ .
#
# Spanish:	¿ Por qué yo ?
# Translation:	Why I ?
# Target:		Why me ?
#
# Spanish:	Isaías 2:2 ; 11:12 .
# Translation:	Isaiah 2:2 ; he 11:12 .
# Target:		Isaiah 2:2 ; 11:12 .
#
# Spanish:	Ezequiel <unk> , 10 .
# Translation:	Ezekiel 33:12 , 10 .
# Target:		Ezekiel <unk> , 10 .
#
# Spanish:	Números 12:6 , 8 .
# Translation:	Numbers 2:11 , 8 .
# Target:		Numbers 12:6 , 8 .
#
# Spanish:	Cito de su historia :
# Translation:	I quote from his story :
# Target:		I quote from his history :
#
# Spanish:	y ellas no mejorarán .
# Translation:	And they will not forsake them .
# Target:		Those things will not get better .
#
# Spanish:	Sesión del domingo por la mañana
# Translation:	Sunday Morning Session
# Target:		Sunday Morning Session
#
# Spanish:	Gratitud en el día de reposo
# Translation:	Gratitude on the Sabbath
# Target:		Gratitude on the Sabbath Day
#
# Spanish:	1 . Aprender nuestro deber .
# Translation:	1 . We Learn .
# Target:		1 . Learning Our Duty
#
# Spanish:	Deuteronomio 4:9 ; cursiva agregada .
# Translation:	Deuteronomy 5:14–15 ; emphasis added .
# Target:		Deuteronomy 4:9 ; emphasis added .
#
# Spanish:	1 Nefi 2:11 , 12 .
# Translation:	1 Nephi 2:11 , 12 .
# Target:		1 Nephi 2:11 , 12 .
#
# Spanish:	ha de volver a nosotros .
# Translation:	He has to come back .
# Target:		Comes back into our own .
#
# Spanish:	¿ Permanecemos en lugares santos ?
# Translation:	Are we standing in holy places ?
# Target:		Are we standing in holy places ?
#
# Spanish:	Caroline decidió seguir el plan .
# Translation:	Caroline decided to follow the plan .
# Target:		Caroline made the choice to follow the plan .
#
# Spanish:	Aquí para servir en una causa noble
# Translation:	Here to Serve a Righteous Cause
# Target:		Here to Serve a Righteous Cause
#
# Spanish:	Mi urgencia los sorprendió un poco .
# Translation:	My urgency surprised a little .
# Target:		My urgency startled them a little .
#
# Spanish:	Véase Juan 15:26 ; Romanos 8:16 .
# Translation:	See John 15:26 ; Romans 8:16 .
# Target:		See John 15:26 ; Romans 8:16 .
#
# Spanish:	Soy el Hijo de Dios ” .
# Translation:	I am the Son of God . ”
# Target:		I am the Son of God . ”
#
# Spanish:	Consideren de qué pecados debemos arrepentirnos .
# Translation:	Consider what sins we must repent .
# Target:		Consider what sins we need to repent of .
#
# Spanish:	Me encanta la historia de la Iglesia .
# Translation:	I love the story of the Church .
# Target:		I love Church history .
#
# Spanish:	Él sabe la mejor manera de ayudarnos .
# Translation:	He knows the best way to help us .
# Target:		He knows best how to help .
#
# Spanish:	Doctrina y Convenios 93:1 ; cursiva agregada .
# Translation:	Doctrine and Covenants know ; emphasis added .
# Target:		Doctrine and Covenants 93:1 ; emphasis added .
#
# Spanish:	Sin ella , yo no estaría aquí ;
# Translation:	I was not here .
# Target:		I would not be here without her .
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:	In the name of Jesus Christ , amen .
# Target:		In the name of Jesus Christ , amen .
#
# Spanish:	Se había desatado la Segunda Guerra Mundial .
# Translation:	There were straight to World War II .
# Target:		World War II had exploded across the world .
#
# Spanish:	Incluya la conferencia general en su diario vivir
# Translation:	Conference Photography
# Target:		Include General Conference in Your Day - to - Day Life
#
# Spanish:	Mantener a la familia es una actividad consagrada .
# Translation:	To Hold the family is a consecrated family .
# Target:		<unk> is a consecrated activity .
#
# Spanish:	¿ Cómo te sientes cuanto te arrepientes ? :
# Translation:	How do you feel you repent ?
# Target:		How do you feel when you repent ?
#
# Spanish:	Véase Juan 14:26 ; D. y C. 35:19 .
# Translation:	See John 14:26 ; Doctrine and Covenants 18:34–36 .
# Target:		See John 14:26 ; Doctrine and Covenants 35:19 .
#
# Spanish:	Se me ha pedido que dirija esta sesión .
# Translation:	I have asked this session .
# Target:		I have been asked to conduct this session .
#
# Spanish:	“ El Salvador los sanaba a todos ” .
# Translation:	“ The Savior will pour all all around us . ”
# Target:		“ The Savior did heal them every one . ”
#
# Spanish:	Pueden orar cuando el coro vaya a cantar .
# Translation:	You can pray when the choir will go to sing .
# Target:		You can pray as the choir is about to sing .
#
# Spanish:	También será nuestra la senda de la tentación .
# Translation:	It will also be our path of temptation .
# Target:		The path of temptation too will be the path of each .
#
# Spanish:	La conferencia general : Fortalece la fe y el testimonio
# Translation:	Conference Report , Strengthen Faith and Testimony
# Target:		General Conference : Strengthening Faith and Testimony
#
# Spanish:	¡ Allí está , arrastrándose hacia el pantano ! .
# Translation:	There is , USA
# Target:		There he is crawling into a <unk> !
#
# Spanish:	Sabemos que el Señor hace intrépidos a Sus siervos .
# Translation:	We know that the Lord does not measure His servants .
# Target:		We know the Lord makes His servants bold .
#
# Spanish:	Quinto , no olviden que el Señor las ama .
# Translation:	Fifth , do n’t forget that the Lord loves you .
# Target:		Fifth , forget not that the Lord loves you .
#
# Spanish:	“ El sacerdocio se dio primeramente a Adán ” .
# Translation:	“ The priesthood was first gave unto Adam . ”
# Target:		“ The Priesthood was first given to Adam . ”
#
# Spanish:	Ahora espero con anhelo pertenecer a un nuevo cuórum .
# Translation:	I now expect to see belonging to a new quorum .
# Target:		Now I look forward to belonging to a new quorum .
#
# Spanish:	Haríamos bien en seguir el ejemplo de nuestro Maestro .
# Translation:	We would do well to follow the example of our Master .
# Target:		We would do well to follow the example of our Master .
#
# Spanish:	Nos sentamos y hablamos acerca de qué debíamos hacer .
# Translation:	We sat down and tell us what we should do .
# Target:		We sat down , and we talked about what we should do . We made a plan .
#
# Spanish:	Primera Consejera de la Presidencia General de la Sociedad de Socorro
# Translation:	First Counselor in the Relief Society General Presidency
# Target:		First Counselor in the Relief Society General Presidency
#
# Spanish:	Cuando el <unk> aflige a su rival , se regocijan .
# Translation:	When you indulge in your peers , you humbly rejoice .
# Target:		When ill fortune afflicts their rival , they rejoice .
#
# Spanish:	El camino del sacerdocio es un trayecto lleno de gozo .
# Translation:	The path of the priesthood is a journey filled with joy .
# Target:		The priesthood path is a journey filled with joy .
#
# Spanish:	La preparación en el sacerdocio : “ Necesito tu ayuda ”
# Translation:	Preparation for the priesthood : “ I Need Thee ”
# Target:		Preparation in the Priesthood : “ I Need Your Help ”
#
# Spanish:	Mis hijos hacen muchas de sus tareas escolares por internet .
# Translation:	My children make many of their school interests at the Internet .
# Target:		My children do much of their schoolwork through the Internet .
#
# Spanish:	Me dijo que guardara el dólar y no lo perdiera .
# Translation:	He told me to keep the dollar and never lose it .
# Target:		He told me to keep the dollar and never lose it .
#
# Spanish:	Como verdaderos hermanos , <unk> por ellos y los fortalecerán .
# Translation:	As true brothers , you indulge in and will strengthen them .
# Target:		Like a true brother , you will watch over and strengthen them .
#
# Spanish:	Él sabe cuándo están perdidos y Él sabe dónde están .
# Translation:	He knows when you are lost and He knows where you are .
# Target:		He knows when you are lost , and He knows where you are .
#
# Spanish:	" No os dejaré huérfanos ; vendré a vosotros " .
# Translation:	" I will not leave you comfortless : I will come to you . "
# Target:		" I will not leave you comfortless : I will come to you , " He promises .
#
# Spanish:	Después , deben imprimir un formulario de Solicitud de ordenanzas familiares .
# Translation:	Then you must be uplifted by a Family Ordinance Request , .
# Target:		Then you print out a Family Ordinance Request .
#
# Spanish:	Él contestará nuestras oraciones ( véase D. y C. 112:10 ) .
# Translation:	He will answer our prayers ( see D&C 112:10 ) .
# Target:		He will answer our prayers ( see D&C 112:10 ) .
#
# Spanish:	El cuarto enseña la importancia de los principios y ordenanzas básicos .
# Translation:	On fourth teaches the importance of principles and basic ordinances .
# Target:		The fourth teaches the importance of basic principles and ordinances .
#
# Spanish:	Los jóvenes deben saber cómo buscar la guía del Padre Celestial .
# Translation:	Youth should learn how to seek Heavenly Father ’s guide .
# Target:		Our youth must know how to seek Heavenly Father ’s guidance .
#
# Spanish:	“ Aunque colmados de pesar ” , Himnos , Nº 63 .
# Translation:	“ Though I filled with sorrow , ” Hymns , no . 63 .
# Target:		“ Though <unk> Trials , ” Hymns , no . 122 .
#
# Spanish:	El Señor confía en aquel que es obediente a Sus mandamientos .
# Translation:	The Lord trusts you is obedient to His commandments .
# Target:		One who is obedient to His commandments is trusted of the Lord .
#
# Spanish:	Recordar cuando fue llevado ante Pilato y Herodes para ser juzgado .
# Translation:	To remember when He was taken to Pilate and Herod .
# Target:		To remember when He was taken to Pilate and to Herod for trial .
#
# Spanish:	Ella había experimentado el poder sanador de la expiación del Salvador .
# Translation:	She had experienced the healing power of the Savior ’s Atonement .
# Target:		She had felt the healing power of the Savior ’s Atonement for her .
#
# Spanish:	El Señor les aconsejó “ sufrir con paciencia sus aflicciones ” .
# Translation:	The Lord counseled you to “ suffer with patience . ”
# Target:		They were counseled by the Lord to “ bear with patience their afflictions . ”
#
# Spanish:	haciendo caso omiso a mis súplicas de que no fueran tan rápido .
# Translation:	He then ignore my pleadings .
# Target:		They ignored my petitions to slow down .
#
# Spanish:	Él es “ … la luz que brilla en las tinieblas ” .
# Translation:	He is “ the light which shineth in darkness . ”
# Target:		He is “ the light which shineth in darkness . ”
#
# Spanish:	Pocos sentimientos se comparan con las tiernas emociones de convertirse en padre .
# Translation:	Few feelings was activated with the tender emotions of becoming fathers .
# Target:		Few feelings compare with the tender emotions of becoming a parent .
#
# Spanish:	Al igual que el hijo pródigo , “ volvió en sí ” .
# Translation:	Like the prodigal son , “ He came to himself . ”
# Target:		Like the prodigal son , “ he came to himself . ”
#
# Spanish:	Con el espíritu de esa instrucción es que me dirijo a ustedes .
# Translation:	With the spirit of that instruction is now to you .
# Target:		It is in the spirit of that instruction that I address you .
#
# Spanish:	Véase UNICEF , “ Young Child <unk> and Development ” , <unk> .
# Translation:	See UNICEF , “ Young Child Trends Economies and Development , ” unhcr.org.uk/about-us/key-facts-and-figures.html .
# Target:		See UNICEF , “ Young Child Survival and Development , ” <unk> .
#
# Spanish:	Escuchamos también ejemplos de ello entre personas de fe en otras iglesias .
# Translation:	We also listen to these examples of faith in other faiths .
# Target:		We also hear examples of this among people of faith in other churches .
#
# Spanish:	Tomamos el nombre de Cristo sobre nosotros en las aguas del bautismo .
# Translation:	For many , the illness of depression is strange or halt .
# Target:		For many , the infirmity of depression is painful or permanently disabling .
#
# Spanish:	Una misión es un acto de servicio voluntario hacia Dios y hacia la humanidad .
# Translation:	A mission is a act of service towards God and mankind .
# Target:		A mission is a <unk> act of service to God and humankind .
#
# Spanish:	y nuestra alma se santifica cuando recibimos el Espíritu Santo con un corazón sincero .
# Translation:	And our souls sanctifies when we receive the Holy Ghost with a sincere heart .
# Target:		Our souls are sanctified when we receive the Holy Ghost with open hearts .
#
# Spanish:	Véase " Lean on My Ample Arm " , Hymns , nro . 120 .
# Translation:	See " Read " My Ample Arm , " Hymns , no . 120 .
# Target:		" Lean on My Ample Arm , " Hymns , no . 120 .
#
# Spanish:	Para que el arrepentimiento surta efecto , debe ser específico , profundo y duradero .
# Translation:	For repentance , it must be specific and lasting , lasting , and abiding .
# Target:		For repentance to work , it must be specific , profound , and lasting .
#
# Spanish:	Piensen en eso : cada una de nosotras tiene un lugar en Su corazón .
# Translation:	Think of that : each of us has a place in His heart .
# Target:		Think of it — each of us holds such a place in His heart .
#
# Spanish:	Ellos ofrecieron el sacrificio , recogieron la sangre y la pusieron en sus hogares .
# Translation:	They offered the sacrifice , broken blood , and the blood at their homes .
# Target:		They offered the sacrifice , collected the blood , and applied it to their homes .
#
# Spanish:	Es especialmente importante recordar la humildad cuando sienten que surge contención en el hogar .
# Translation:	It is especially important to remember humility when you feel contention will be touched in the home .
# Target:		It is especially important to remember humility when you feel contention rising in your home .
#
# Spanish:	“ Y parte cayó entre espinos , y los espinos crecieron y la ahogaron .
# Translation:	“ And there fell among thorns , and thorns , and choked it , and choked it :
# Target:		“ And some fell among thorns ; and the thorns sprung up , and choked them :
#
# Spanish:	Les daré un ejemplo de lo que puede hacer un maestro orientador al orar .
# Translation:	I will give you an example of what you can do a home teacher as you pray .
# Target:		I will give you an example of what a home teacher might do as he prays .
#
# Spanish:	Mis padres recibieron algunas lecciones y luego mi padre ya no tuvo más interés .
# Translation:	My parents received some lessons and then my father had no more interest .
# Target:		My parents took a few lessons , and then my father did n’t have any more interest .
#
# Spanish:	Testifico que Él vive ; y lo hago en Su santo nombre . Amén .
# Translation:	I testify that He lives , and I do so in His holy name , amen .
# Target:		I testify that He lives and bear this witness in His holy name , the name of Jesus Christ , amen .
#
# Spanish:	“ Estos que están vestidos de ropas blancas , ¿ quiénes son … ? ” .
# Translation:	“ These are cast in white , O who are … who are … ? ”
# Target:		“ What are these which are arrayed in white ? ”
#
# Spanish:	Cada una de nosotras pertenece a la familia de Dios y es necesaria en ella .
# Translation:	Each of us is one of us and is needed in it .
# Target:		We each belong to and are needed in the family of God .
#
# Spanish:	En ocasiones , tenía que detenerse para controlar sus emociones antes de finalizar la oración .
# Translation:	Sometimes she had stop being able to control her emotions before we concluded .
# Target:		He sometimes had to pause to control his emotions before completing the prayer .
#
# Spanish:	Predicad Mi Evangelio : Una guía para el servicio misional , 2004 , pág. 217 .
# Translation:	Preach My Gospel : A Guide to Missionary Service ( 2004 ) , 218 .
#
# Spanish:	Las fotografías de la conferencia general en Salt Lake City fueron tomadas por Welden C. Andersen , <unk> Bell , Cody Bell , Janae Bingham , Ale Borges , Randy Collier , Mark Davis , Nate Edwards , Brian Nicholson , Leslie Nilsson , Matt Reier , Bradley <unk> y Christina Smith ; de la familia Cavalcante , cortesía de Aroldo Cavalcante ; en <unk> , Georgia , EE.UU . , por Whitney <unk> ; en el condado de <unk> , California , EE.UU . , por Erik <unk> ; de la familia Openshaw , cortesía de la familia Openshaw ; en <unk> , India , por Wendy <unk> <unk> ; en <unk> y <unk> , Noruega , por Ashlee Larsen ; en Kiev , Ucrania , por Marina <unk> ; en San Pedro , <unk> , por Josué Peña ; en <unk> , Chile , por <unk> Jeanne Randall ; en <unk> , <unk> , México , por <unk> Castañeda Reyes ; en Ciudad <unk> , <unk> , Filipinas , por Danny <unk> .
# Translation:	Photographs in Salt Lake City were taken by Welden C. Andersen , Cody Bell , Ale Borges , Ale Borges , Randy Collier , Mark Davis , Mark Davis , Mark Davis , Ashlee Larsen , Leslie Nilsson , Matt Reier , and Christina Hansen ; of Yvette Bugingo ; of Jones ; in Sweden .
# Target:		Photographs in Salt Lake City were taken by Welden C. Andersen , <unk> Bell , Cody Bell , Janae Bingham , Ale Borges , Randy Collier , Mark Davis , Nate Edwards , Brian Nicholson , Leslie Nilsson , Matt Reier , Bradley <unk> , and Christina Smith ; of the Cavalcante family , courtesy of Aroldo Cavalcante ; in Athens , Georgia , USA , by Whitney <unk> ; in <unk> County , California , USA , by Erik <unk> ; of Openshaw family members , courtesy of the Openshaw family ; in <unk> , India , by Wendy <unk> <unk> ; in <unk> and <unk> , Norway , by Ashlee Larsen ; in Kyiv , Ukraine , by <unk> <unk> ; in San Pedro , <unk> , by Josué Peña ; in <unk> , Chile , by <unk> Jeanne Randall ; in <unk> , <unk> , Mexico , by <unk> Castañeda Reyes ; in <unk> City , <unk> , Philippines , by Danny <unk> .

# %% [markdown]
# <div id="disqus_thread"></div>
# <script>
#     /**
#      *  RECOMMENDED CONFIGURATION VARIABLES: EDIT AND UNCOMMENT THE SECTION BELOW TO INSERT DYNAMIC VALUES FROM YOUR PLATFORM OR CMS.
#      *  LEARN WHY DEFINING THESE VARIABLES IS IMPORTANT: https://disqus.com/admin/universalcode/#configuration-variables
#      */
#     /*
#     var disqus_config = function () {
#         this.page.url = PAGE_URL;  // Replace PAGE_URL with your page's canonical URL variable
#         this.page.identifier = PAGE_IDENTIFIER; // Replace PAGE_IDENTIFIER with your page's unique identifier variable
#     };
#     */
#     (function() {  // REQUIRED CONFIGURATION VARIABLE: EDIT THE SHORTNAME BELOW
#         var d = document, s = d.createElement('script');
#
#         s.src = 'https://EXAMPLE.disqus.com/embed.js';  // IMPORTANT: Replace EXAMPLE with your forum shortname!
#
#         s.setAttribute('data-timestamp', +new Date());
#         (d.head || d.body).appendChild(s);
#     })();
# </script>
# <noscript>Please enable JavaScript to view the <a href="https://disqus.com/?ref_noscript" rel="nofollow">comments powered by Disqus.</a></noscript>
